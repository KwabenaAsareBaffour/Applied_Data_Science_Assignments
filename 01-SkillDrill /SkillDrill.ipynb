# %%
# Import dependencies
import pandas as pd
import os

# %%
# Read file into DataFrame
ratings = os.path.join("/Users","kasarebaffour","temp-notebooks","NFLX-VIRT-DATA-PT-08-2021-E-LOL","02-Assignments","02-Pandas","01-SkillDrill","Resources","ratings_and_sentiments.csv")
data = pd.read_csv(ratings)
data.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                          review_text           rating  \
# 0  11/25/2016 1 check-in Love love loved the vibe...  5.0 star rating
# 1  12/2/2016 Listed in Date Night: Austin, vibe i...  4.0 star rating
# 2  11/30/2016 1 check-in Listed in food seating I...  4.0 star rating
# 3  11/25/2016 Very cool vibe! Good drinks Nice se...  2.0 star rating
# 4  12/3/2016 1 check-in They are location within ...  4.0 star rating
#
#    num_rating cat_rating  bool_HIGH  overall_sent vibe_sent  tea_sent  \
# 0           5       HIGH          1             4         3         0
# 1           4       HIGH          1             3         3         0
# 2           4       HIGH          1             2         2         0
# ...

# %%
# Find all reviews with a number rating greater than or equal to 4.
data_df=data[data.iloc[:,3]>=4]
data_df
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# 5     The Factory - Cafe With a Soul
# ...                               ...
# 7610               The Steeping Room
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7615               The Steeping Room
#
#                                             review_text           rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...  5.0 star rating
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...  4.0 star rating
# 2     11/30/2016 1 check-in Listed in food seating I...  4.0 star rating
# 4     12/3/2016 1 check-in They are location within ...  4.0 star rating
# 5     11/20/2016 1 check-in Very cute cafe! I think ...  4.0 star rating
# ...

# %%
# Find all the coffee shops with a overall sentiment greater than or equal to 4.
data_df = data[data.iloc[:,6]>=4]
data_df
# Out:
#                           coffee_shop_name  \
# 0          The Factory - Cafe With a Soul
# 233              Mozart's Coffee Roasters
# 931                Venezia Italian Gelato
# 1101       The Factory - Cafe With a Soul
# 1466             Figure 8 Coffee Purveyors
# 1591               MaГ±ana Coffee & Juice
# 2008       The Factory - Cafe With a Soul
# 2213                    Flat Track Coffee
# 2595               Flightpath Coffeehouse
# 2681  Third Coast Coffee Roasting Company
# 2831                           Dolce Neve
# 3051                              Halcyon
# 3106       The Factory - Cafe With a Soul
# 3390            Arturo's Underground Cafe
# 3425            Arturo's Underground Cafe
# 3787                     Lucky Lab Coffee
# 4137                              Halcyon
# 4419                             Tea Haus
# 4515                  Friends & Neighbors
# 4530                    Sorrento's Coffee
# 4576                    Sorrento's Coffee
# ...

# %%
# Return the count of the above query.
returning_count = data_df.count()
returning_count
# Out:
# coffee_shop_name    32
# review_text         32
# rating              32
# num_rating          32
# cat_rating          32
# bool_HIGH           32
# overall_sent        32
# vibe_sent           18
# tea_sent            32
# service_sent        32
# seating_sent        32
# price_sent          32
# parking_sent        32
# location_sent       32
# alcohol_sent        32
# coffee_sent         32
# food_sent           32
# hours_sent          32
# internet_sent       32
# local_sent          32
# dtype: int64

# %%
# Change the name of the review_text column to review
data_df.rename(columns={"review_text":"review"})
# Out:
#                           coffee_shop_name  \
# 0          The Factory - Cafe With a Soul
# 233              Mozart's Coffee Roasters
# 931                Venezia Italian Gelato
# 1101       The Factory - Cafe With a Soul
# 1466             Figure 8 Coffee Purveyors
# 1591               MaГ±ana Coffee & Juice
# 2008       The Factory - Cafe With a Soul
# 2213                    Flat Track Coffee
# 2595               Flightpath Coffeehouse
# 2681  Third Coast Coffee Roasting Company
# 2831                           Dolce Neve
# 3051                              Halcyon
# 3106       The Factory - Cafe With a Soul
# 3390            Arturo's Underground Cafe
# 3425            Arturo's Underground Cafe
# 3787                     Lucky Lab Coffee
# 4137                              Halcyon
# 4419                             Tea Haus
# 4515                  Friends & Neighbors
# 4530                    Sorrento's Coffee
# 4576                    Sorrento's Coffee
# ...

# %%
# Change the name of the bool_HIGH column to bool_high
data_df.rename(columns={"bool_HIGH":"bool_high"})
# Out:
#                           coffee_shop_name  \
# 0          The Factory - Cafe With a Soul
# 233              Mozart's Coffee Roasters
# 931                Venezia Italian Gelato
# 1101       The Factory - Cafe With a Soul
# 1466             Figure 8 Coffee Purveyors
# 1591               MaГ±ana Coffee & Juice
# 2008       The Factory - Cafe With a Soul
# 2213                    Flat Track Coffee
# 2595               Flightpath Coffeehouse
# 2681  Third Coast Coffee Roasting Company
# 2831                           Dolce Neve
# 3051                              Halcyon
# 3106       The Factory - Cafe With a Soul
# 3390            Arturo's Underground Cafe
# 3425            Arturo's Underground Cafe
# 3787                     Lucky Lab Coffee
# 4137                              Halcyon
# 4419                             Tea Haus
# 4515                  Friends & Neighbors
# 4530                    Sorrento's Coffee
# 4576                    Sorrento's Coffee
# ...

# %%
# Save your changes to the file as a pipe delimited file.
data_df.to_csv('data_df.txt', sep = '|')
